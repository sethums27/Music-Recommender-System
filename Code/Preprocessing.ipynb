# %%
import numpy as np
import pandas as pd
df=pd.read_csv("sample_data/tweet_emotions.csv")
df.head(10)
# Out:
#      tweet_id   sentiment                                            content
# 0  1956967341       empty  @tiffanylue i know  i was listenin to bad habi...
# 1  1956967666     sadness  Layin n bed with a headache  ughhhh...waitin o...
# 2  1956967696     sadness                Funeral ceremony...gloomy friday...
# 3  1956967789  enthusiasm               wants to hang out with friends SOON!
# 4  1956968416     neutral  @dannycastillo We want to trade with someone w...
# 5  1956968477       worry  Re-pinging @ghostridah14: why didn't you go to...
# 6  1956968487     sadness  I should be sleep, but im not! thinking about ...
# 7  1956968636       worry               Hmmm. http://www.djhero.com/ is down
# 8  1956969035     sadness            @charviray Charlene my love. I miss you
# 9  1956969172     sadness         @kelcouch I'm sorry  at least it's Friday?

# %%
df
# Out:
#          tweet_id   sentiment  \
# 0      1956967341       empty
# 1      1956967666     sadness
# 2      1956967696     sadness
# 3      1956967789  enthusiasm
# 4      1956968416     neutral
# ...           ...         ...
# 39995  1753918954     neutral
# 39996  1753919001        love
# 39997  1753919005        love
# 39998  1753919043   happiness
# 39999  1753919049        love
#
#                                                  content
# 0      @tiffanylue i know  i was listenin to bad habi...
# 1      Layin n bed with a headache  ughhhh...waitin o...
# 2                    Funeral ceremony...gloomy friday...
# 3                   wants to hang out with friends SOON!
# 4      @dannycastillo We want to trade with someone w...
# ...                                                  ...
# 39995                                   @JohnLloydTaylor
# 39996                     Happy Mothers Day  All my love
# 39997  Happy Mother's Day to all the mommies out ther...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tweet_id   40000 non-null  int64
#  1   sentiment  40000 non-null  object
#  2   content    40000 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 937.6+ KB

# %%
df.isnull()
# Out:
#        tweet_id  sentiment  content
# 0         False      False    False
# 1         False      False    False
# 2         False      False    False
# 3         False      False    False
# 4         False      False    False
# ...         ...        ...      ...
# 39995     False      False    False
# 39996     False      False    False
# 39997     False      False    False
# 39998     False      False    False
# 39999     False      False    False
#
# [40000 rows x 3 columns]

# %%
idx = df[(df['sentiment']=='disgust') | (df['sentiment']=='fear') | (df['sentiment']=='angry') | (df['sentiment']=='surprise')].index

# %%
df.drop(idx , inplace=True)

# %%
df
# Out:
#          tweet_id   sentiment  \
# 0      1956967341       empty
# 1      1956967666     sadness
# 2      1956967696     sadness
# 3      1956967789  enthusiasm
# 4      1956968416     neutral
# ...           ...         ...
# 39995  1753918954     neutral
# 39996  1753919001        love
# 39997  1753919005        love
# 39998  1753919043   happiness
# 39999  1753919049        love
#
#                                                  content
# 0      @tiffanylue i know  i was listenin to bad habi...
# 1      Layin n bed with a headache  ughhhh...waitin o...
# 2                    Funeral ceremony...gloomy friday...
# 3                   wants to hang out with friends SOON!
# 4      @dannycastillo We want to trade with someone w...
# ...                                                  ...
# 39995                                   @JohnLloydTaylor
# 39996                     Happy Mothers Day  All my love
# 39997  Happy Mother's Day to all the mommies out ther...
# ...

# %%
import matplotlib.pyplot as plt

# %%
emo_count=df.value_counts('sentiment')

# %%
emo_count.plot(kind='pie')
plt.show()

# %%
df
# Out:
#          tweet_id   sentiment  \
# 0      1956967341       empty
# 1      1956967666     sadness
# 2      1956967696     sadness
# 3      1956967789  enthusiasm
# 4      1956968416     neutral
# ...           ...         ...
# 39995  1753918954     neutral
# 39996  1753919001        love
# 39997  1753919005        love
# 39998  1753919043   happiness
# 39999  1753919049        love
#
#                                                  content
# 0      @tiffanylue i know  i was listenin to bad habi...
# 1      Layin n bed with a headache  ughhhh...waitin o...
# 2                    Funeral ceremony...gloomy friday...
# 3                   wants to hang out with friends SOON!
# 4      @dannycastillo We want to trade with someone w...
# ...                                                  ...
# 39995                                   @JohnLloydTaylor
# 39996                     Happy Mothers Day  All my love
# 39997  Happy Mother's Day to all the mommies out ther...
# ...

# %%
df.value_counts('sentiment')
# Out:
# sentiment
# neutral       8638
# worry         8459
# happiness     5209
# sadness       5165
# love          3842
# surprise      2187
# fun           1776
# relief        1526
# hate          1323
# empty          827
# enthusiasm     759
# boredom        179
# anger          110
# dtype: int64

# %%
df.drop(df[df['sentiment'] == 'disgust'].index, inplace = True)

# %%
df.head()
# Out:
#      tweet_id   sentiment                                            content
# 1  1956967666     sadness  Layin n bed with a headache  ughhhh...waitin o...
# 2  1956967696     sadness                Funeral ceremony...gloomy friday...
# 3  1956967789  enthusiasm               wants to hang out with friends SOON!
# 4  1956968416     neutral  @dannycastillo We want to trade with someone w...
# 5  1956968477       worry  Re-pinging @ghostridah14: why didn't you go to...

# %%
df.drop(df[df['sentiment'] =='enthusiasm'].index, inplace = True)

# %%
df.drop(df[df['sentiment'] =='fun'].index, inplace = True)

# %%
df.drop(df[df['sentiment'] =='relief'].index, inplace = True)

# %%
df.drop(df[df['sentiment'] =='love'].index, inplace = True)

# %%
df.drop(df[df['sentiment'] =='anger'].index, inplace = True)

# %%
print("\nUnique values from a column ...\n",df['sentiment'].unique())
# Out:
# Unique values from a column ...
#  ['sad' 'neutral' 'happy']

# %%
df['sentiment'].hist()
plt.show()

# %%
df['sentiment'] = df['sentiment'].replace({'sadness': 'sad'})
  
# writing into the file
df.to_csv("sample_data/tweet_emotions.csv", index=False)
  
print(df)
# Out:
#          tweet_id  sentiment  \
# 0      1956967341      empty
# 1      1956967666        sad
# 2      1956967696        sad
# 4      1956968416    neutral
# 5      1956968477      worry
# ...           ...        ...
# 39992  1753918881    neutral
# 39993  1753918892    neutral
# 39994  1753918900  happiness
# 39995  1753918954    neutral
# 39998  1753919043  happiness
#
#                                                  content
# 0      @tiffanylue i know  i was listenin to bad habi...
# 1      Layin n bed with a headache  ughhhh...waitin o...
# 2                    Funeral ceremony...gloomy friday...
# 4      @dannycastillo We want to trade with someone w...
# 5      Re-pinging @ghostridah14: why didn't you go to...
# ...                                                  ...
# 39992  @jasimmo Ooo showing of your French skills!! l...
# 39993  @sendsome2me haha, yeah. Twitter has many uses...
# 39994                      Succesfully following Tayla!!
# ...

# %%
df.head()
# Out:
#      tweet_id sentiment                                            content
# 1  1956967666       sad  Layin n bed with a headache  ughhhh...waitin o...
# 2  1956967696       sad                Funeral ceremony...gloomy friday...
# 4  1956968416   neutral  @dannycastillo We want to trade with someone w...
# 5  1956968477     worry  Re-pinging @ghostridah14: why didn't you go to...
# 6  1956968487       sad  I should be sleep, but im not! thinking about ...

# %%
df['sentiment'] = df['sentiment'].replace({'worry': 'fear'})
  
# writing into the file
df.to_csv("sample_data/tweet_emotions.csv", index=False)
  
print(df)
# Out:
#          tweet_id  sentiment  \
# 1      1956967666        sad
# 2      1956967696        sad
# 4      1956968416    neutral
# 5      1956968477       fear
# 6      1956968487        sad
# ...           ...        ...
# 39992  1753918881    neutral
# 39993  1753918892    neutral
# 39994  1753918900  happiness
# 39995  1753918954    neutral
# 39998  1753919043  happiness
#
#                                                  content
# 1      Layin n bed with a headache  ughhhh...waitin o...
# 2                    Funeral ceremony...gloomy friday...
# 4      @dannycastillo We want to trade with someone w...
# 5      Re-pinging @ghostridah14: why didn't you go to...
# 6      I should be sleep, but im not! thinking about ...
# ...                                                  ...
# 39992  @jasimmo Ooo showing of your French skills!! l...
# 39993  @sendsome2me haha, yeah. Twitter has many uses...
# 39994                      Succesfully following Tayla!!
# ...

# %%
df['sentiment'] = df['sentiment'].replace({'happiness': 'happy'})
  
# writing into the file
df.to_csv("sample_data/tweet_emotions.csv", index=False)
  
print(df)
# Out:
#          tweet_id sentiment                                            content
# 1      1956967666       sad  Layin n bed with a headache  ughhhh...waitin o...
# 2      1956967696       sad                Funeral ceremony...gloomy friday...
# 4      1956968416   neutral  @dannycastillo We want to trade with someone w...
# 6      1956968487       sad  I should be sleep, but im not! thinking about ...
# 8      1956969035       sad            @charviray Charlene my love. I miss you
# ...           ...       ...                                                ...
# 39992  1753918881   neutral  @jasimmo Ooo showing of your French skills!! l...
# 39993  1753918892   neutral  @sendsome2me haha, yeah. Twitter has many uses...
# 39994  1753918900     happy                      Succesfully following Tayla!!
# 39995  1753918954   neutral                                   @JohnLloydTaylor
# 39998  1753919043     happy  @niariley WASSUP BEAUTIFUL!!! FOLLOW ME!!  PEE...
#
# ...

# %%
df['sentiment'] = df['sentiment'].replace({'hate': 'disgust'})
  
# writing into the file
df.to_csv("sample_data/tweet_emotions.csv", index=False)
  
print(df)
# Out:
#          tweet_id sentiment                                            content
# 1      1956967666       sad  Layin n bed with a headache  ughhhh...waitin o...
# 2      1956967696       sad                Funeral ceremony...gloomy friday...
# 4      1956968416   neutral  @dannycastillo We want to trade with someone w...
# 5      1956968477      fear  Re-pinging @ghostridah14: why didn't you go to...
# 6      1956968487       sad  I should be sleep, but im not! thinking about ...
# ...           ...       ...                                                ...
# 39992  1753918881   neutral  @jasimmo Ooo showing of your French skills!! l...
# 39993  1753918892   neutral  @sendsome2me haha, yeah. Twitter has many uses...
# 39994  1753918900     happy                      Succesfully following Tayla!!
# 39995  1753918954   neutral                                   @JohnLloydTaylor
# 39998  1753919043     happy  @niariley WASSUP BEAUTIFUL!!! FOLLOW ME!!  PEE...
#
# ...

# %%
df['sentiment'] = df['sentiment'].replace({'anger': 'angry'})
  
# writing into the file
df.to_csv("sample_data/tweet_emotions.csv", index=False)
  
print(df)
# Out:
#          tweet_id sentiment                                            content
# 1      1956967666       sad  Layin n bed with a headache  ughhhh...waitin o...
# 2      1956967696       sad                Funeral ceremony...gloomy friday...
# 4      1956968416   neutral  @dannycastillo We want to trade with someone w...
# 5      1956968477      fear  Re-pinging @ghostridah14: why didn't you go to...
# 6      1956968487       sad  I should be sleep, but im not! thinking about ...
# ...           ...       ...                                                ...
# 39992  1753918881   neutral  @jasimmo Ooo showing of your French skills!! l...
# 39993  1753918892   neutral  @sendsome2me haha, yeah. Twitter has many uses...
# 39994  1753918900     happy                      Succesfully following Tayla!!
# 39995  1753918954   neutral                                   @JohnLloydTaylor
# 39998  1753919043     happy  @niariley WASSUP BEAUTIFUL!!! FOLLOW ME!!  PEE...
#
# ...

# %%
df.head()
# Out:
#      tweet_id sentiment                                            content
# 1  1956967666       sad  Layin n bed with a headache  ughhhh...waitin o...
# 2  1956967696       sad                Funeral ceremony...gloomy friday...
# 4  1956968416   neutral  @dannycastillo We want to trade with someone w...
# 5  1956968477      fear  Re-pinging @ghostridah14: why didn't you go to...
# 6  1956968487       sad  I should be sleep, but im not! thinking about ...

# %%
print("\nUnique values from a column ...\n",df['sentiment'].unique())
# Out:
# Unique values from a column ...
#  ['sad' 'neutral' 'fear' 'surprise' 'disgust' 'happy' 'angry']
